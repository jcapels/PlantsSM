# %%
import pickle

with open("solutions.pkl", "rb") as f:
    solution = pickle.load(f)

# %%
solution[-9].reaction.get_reverse_reaction()
# Out:
# 'CC(C)=CCC/C(C)=C/C=C/C(C)=C/C=C/C(C)=C/C=C/C=C(C)/C=C/C=C(C)/C=C/C=C(\\C)CCC=C(C)C>>CC(C)=CCC/C(C)=C/CC/C(C)=C/C=C/C(C)=C/C=C/C=C(C)/C=C/C=C(C)/C=C/C=C(\\C)CCC=C(C)C'

# %%
import pickle

with open("solution_retrosynthesis.pkl", "rb") as f:
    solution_linker = pickle.load(f)
solution_linker
# Out:
# {'route': [[None,
#    'CC(=O)/C=C/C1=C(C)CCCC1(C)C>>C\\C(\\C=C\\C=C(/C)\\C=C\\C1=C(C)CCCC1(C)C)=C/C=C/C=C(\\C)/C=C/C=C(\\C)C1OC2(C)CCCC(C)(C)C2=C1',
#    'CC(C)=CCC/C(C)=C/CC/C(C)=C/COP(=O)(O)OP(=O)(O)O>>CC(=O)/C=C/C1=C(C)CCCC1(C)C',
#    'CC(C)=CCC/C(C)=C/CC/C(C)=C/CC/C(C)=C/COP(=O)(O)OP(=O)(O)O>>CC(C)=CCC/C(C)=C/CC/C(C)=C/COP(=O)(O)OP(=O)(O)O']],
#  'template': [[None,
#    'CC(=O)/C=C/C1=C(C)CCCC1(C)C>>CC1=C(/C=C/C(C)=C/C=C/C(C)=C/C=C/C=C(C)/C=C/C=C(\\C)C2C=C3C(C)(C)CCCC3(C)O2)C(C)(C)CCC1',
#    'CC(C)=CCC/C(C)=C/CC/C(C)=C/COP(=O)(O)OP(=O)(O)O>>CC(=O)/C=C/C1=C(C)CCCC1(C)C',
#    'CC(C)=CCC/C(C)=C/CC/C(C)=C/CC/C(C)=C/COP(=O)(O)OP(=O)(O)O>>CC(C)=CCC/C(C)=C/CC/C(C)=C/COP(=O)(O)OP(=O)(O)O']],
#  'success': [True],
#  'depth': [3],
#  'counts': [3],
#  'reaction_solutions': [None,
# ...

# %%
print(len(solution_linker["reaction_solutions"][2].enzymes_scores))
# Out:
# 47

# %%
from rdkit import Chem

Chem.MolFromSmiles("CC(C)=CCC/C(C)=C/CC/C(C)=C/CC/C(C)=C/COP(=O)(O)OP(=O)(O)O")

# %%
import pickle

with open("solution_retrosynthesis_retroformer.pkl", "rb") as f:
    solution_linker = pickle.load(f)
solution_linker
# Out:
# {'route': [[None,
#    'CC(C)=CCC/C(C)=C/CC[C@]1(C)[C@@H]2CC3CC(C2)C31C>>CC(=CCCC(C)(C(=O)CCC1(C2CC3C1(C3C2)C)C)O)C',
#    'CC(C)=CCC/C(C)=C/CC/C(C)=C/CC/C(C)=C/COP(=O)(O)OP(=O)(O)O>>CC(C)=CCC/C(C)=C/CC[C@]1(C)[C@@H]2CC3CC(C2)C31C']],
#  'template': [[None,
#    'CC(C)=CCC/C(C)=C/CC[C@]1(C)[C@@H]2CC3CC(C2)C31C>>CC(C)=CCCC(C)(O)C(=O)CCC1(C)C2CC3C(C2)C31C',
#    'CC(C)=CCC/C(C)=C/CC/C(C)=C/CC/C(C)=C/COP(=O)(O)OP(=O)(O)O>>CC(C)=CCC/C(C)=C/CC[C@]1(C)C2CC3CC(C2)C31C']],
#  'success': [True],
#  'depth': [2],
#  'counts': [2],
#  'reaction_solutions': [None,
# ...

# %%
solution_linker[-7].products[0].mol
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 solution_linker[-7].products[0].mol
#
# TypeError: 'SearcherSolution' object is not subscriptable
